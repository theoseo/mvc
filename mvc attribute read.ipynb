# %%
import pandas as pd
mvc_attribute = pd.read_csv( './mvc_data/mvc_attribute_all.csv', index_col='filename')

# %%
mvc_attribute.head(10)
# Out:
#                       AlineDresses  AnimalPrint  Anoraks  Argyle  \
# filename
# p7258521_s3163710_v0             0            0        0       0
# p7258521_s3163710_v1             0            0        0       0
# p7258521_s3163710_v2             0            0        0       0
# p7258521_s3163710_v3             0            0        0       0
# p7258521_s3163710_v4             0            0        0       0
# p7258521_s3163713_v0             0            0        0       0
# p7258521_s3163713_v1             0            0        0       0
# p7258521_s3163713_v2             0            0        0       0
# p7258521_s3163713_v3             0            0        0       0
# p7258521_s3163713_v4             0            0        0       0
#
#                       Asymmetrical  Athletic  BabyDollDresses  BalconetteBras  \
# filename
# p7258521_s3163710_v0             0         0                0               0
# ...

# %%
DATA_DIR = "./mvc_data/dataset"
mvc_path = "./mvc_data"
BOTTLE_DIR = "./mvc_data/bottleneck"
TRAIN_DIR = DATA_DIR + "/train"
VAL_DIR = DATA_DIR + "/validation"
TRAIN_BOTTLE_DIR = BOTTLE_DIR + "/train"
VAL_BOTTLE_DIR = BOTTLE_DIR + "/validation"
file_tail = "_https~tfhub.dev~google~imagenet~pnasnet_large~feature_vector~1.txt"
NUM_TRAIN_EXAMPLES = 0
NUM_VAL_EXAMPLES = 0

eval_info = {}
